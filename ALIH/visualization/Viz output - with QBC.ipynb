# %%
import os
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from io import StringIO

import fnmatch

# %%
output_dir = list(os.listdir('../output'))

# %%
df_template = pd.read_csv(StringIO("""package,time_elapsed,classifier,sample_size,strategy,dataset,accuracy_history,f1_history,id_bag"""))

# %%
df_aux = df_template[:]
for file in output_dir:
    df_aux = pd.concat([df_aux,pd.read_csv('../output/' + file)])

# %%
df_aux['cost'] = df_aux.index

# %%
df_aux["approach"] = df_aux.apply(lambda x: "agnostic" if (x.strategy == "Random Sampling")  else "non agnostic", axis=1)

# %%
df_aux = df_aux \
.replace("Lowest H, Highest U Sampling", "HU") \
.replace("Lowest F3 Sampling", "F3") \
.replace("Lowest N1 Sampling", "N1") \
.replace("Highest LSC Sampling", "LSC") \
.replace("Query by Committee", "QBC") \
.replace("Highest Usefulness Sampling", "U") \
.replace("Random Sampling", "RS") \
.replace("Lowest Harmfulness Sampling", "H") \
.replace("Expected Model Change", "EMC") \
.replace("Uncertain Sampling", "US") \
.replace("upyhard", "pyHard") \
.replace("Pyhard", "pyHard")

# %%
df_aux["package"] = df_aux.apply(lambda x: "Baseline" if (x.strategy == "RS") else "Clássica" if (x.package == "modAL")  else "Proposta", axis=1)

# %%
df_aux["dataset"] = df_aux["dataset"].apply(lambda x: x.split(sep="_")[0])

# %%
df_aux['accuracy_history'] = df_aux['accuracy_history'] *100
df_aux['f1_history'] = df_aux['f1_history'] *100
df_aux['sample_size'] = df_aux['sample_size'] *100

# %%
df_aux

# %% [raw]
# pyhard_datasets = df_aux[(df_aux.strategy != "Lowest N2 Sampling") & (df_aux.strategy == "Lowest N1 Sampling")]['dataset'].unique()

# %%
df_all.to_csv("./compilation_values.csv", index = False)

# %% [markdown]
# ## CSV Compilado pronto

# %%
df_all = pd.read_csv("./compilation_values.csv")

# %%
df_all
# Out:
#          package  time_elapsed classifier  sample_size strategy  dataset  \
# 0       Clássica     54.418267        5NN    68.215695      EMC     1043
# 1       Clássica     54.418267        5NN    68.215695      EMC     1043
# 2       Clássica     54.418267        5NN    68.215695      EMC     1043
# 3       Clássica     54.418267        5NN    68.215695      EMC     1043
# 4       Clássica     54.418267        5NN    68.215695      EMC     1043
# ...          ...           ...        ...          ...      ...      ...
# 269795  Proposta    177.204027         RF   100.000000       F3       60
# 269796  Proposta    177.204027         RF   100.000000       F3       60
# 269797  Proposta    177.204027         RF   100.000000       F3       60
# 269798  Proposta    177.204027         RF   100.000000       F3       60
# 269799  Proposta    177.204027         RF   100.000000       F3       60
#
#         accuracy_history  f1_history  id_bag  cost      approach
# 0              77.108434   76.178276       0     0  non agnostic
# 1              77.108434   75.493640       0     1  non agnostic
# 2              77.546550   75.792694       0     2  non agnostic
# 3              77.984666   76.794328       0     3  non agnostic
# 4              77.108434   75.493640       0     4  non agnostic
# ...                  ...         ...     ...   ...           ...
# 269795         82.300000   85.315712       4    14  non agnostic
# 269796         82.100000   85.666909       4    15  non agnostic
# 269797         82.200000   85.306239       4    16  non agnostic
# 269798         82.300000   85.614706       4    17  non agnostic
# 269799         81.800000   86.049257       4    18  non agnostic
#
# [269800 rows x 11 columns]

# %%
df_all['strategy'].value_counts()
# Out:
# H      26980
# RS     26980
# EMC    26980
# QBC    26980
# HU     26980
# U      26980
# N1     26980
# LSC    26980
# F3     26980
# US     26980
# Name: strategy, dtype: int64

# %%
df_all.rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"}).head(50)
# Out:
#       Pacote  Tempo de execução Classificador  Tamanho da amostra Estratégia  \
# 0   Clássica          54.418267           5NN           68.215695        EMC
# 1   Clássica          54.418267           5NN           68.215695        EMC
# 2   Clássica          54.418267           5NN           68.215695        EMC
# 3   Clássica          54.418267           5NN           68.215695        EMC
# 4   Clássica          54.418267           5NN           68.215695        EMC
# 5   Clássica          54.418267           5NN           68.215695        EMC
# 6   Clássica          54.418267           5NN           68.215695        EMC
# 7   Clássica          54.418267           5NN           68.215695        EMC
# 8   Clássica          54.418267           5NN           68.215695        EMC
# 9   Clássica          54.418267           5NN           68.215695        EMC
# 10  Clássica          54.418267           5NN           68.215695        EMC
# 11  Clássica          54.418267           5NN           68.215695        EMC
# 12  Clássica          54.418267           5NN           68.215695        EMC
# 13  Clássica          54.418267           5NN           68.215695        EMC
# 14  Clássica          54.418267           5NN           68.215695        EMC
# 15  Clássica          54.418267           5NN           68.215695        EMC
# 16  Clássica          54.418267           5NN           68.215695        EMC
# 17  Clássica          54.418267           5NN           68.215695        EMC
# 18  Clássica          54.418267           5NN           68.215695        EMC
# 19  Clássica          51.458460           5NN           43.117054        EMC
# 20  Clássica          51.458460           5NN           43.117054        EMC
# 21  Clássica          51.458460           5NN           43.117054        EMC
# 22  Clássica          51.458460           5NN           43.117054        EMC
# 23  Clássica          51.458460           5NN           43.117054        EMC
# 24  Clássica          51.458460           5NN           43.117054        EMC
# 25  Clássica          51.458460           5NN           43.117054        EMC
# 26  Clássica          51.458460           5NN           43.117054        EMC
# 27  Clássica          51.458460           5NN           43.117054        EMC
# 28  Clássica          51.458460           5NN           43.117054        EMC
# 29  Clássica          51.458460           5NN           43.117054        EMC
# 30  Clássica          51.458460           5NN           43.117054        EMC
# 31  Clássica          51.458460           5NN           43.117054        EMC
# 32  Clássica          51.458460           5NN           43.117054        EMC
# 33  Clássica          51.458460           5NN           43.117054        EMC
# 34  Clássica          51.458460           5NN           43.117054        EMC
# 35  Clássica          51.458460           5NN           43.117054        EMC
# 36  Clássica          51.458460           5NN           43.117054        EMC
# 37  Clássica          51.458460           5NN           43.117054        EMC
# 38  Clássica          54.674571           5NN           33.077598        EMC
# 39  Clássica          54.674571           5NN           33.077598        EMC
# 40  Clássica          54.674571           5NN           33.077598        EMC
# 41  Clássica          54.674571           5NN           33.077598        EMC
# 42  Clássica          54.674571           5NN           33.077598        EMC
# 43  Clássica          54.674571           5NN           33.077598        EMC
# 44  Clássica          54.674571           5NN           33.077598        EMC
# 45  Clássica          54.674571           5NN           33.077598        EMC
# 46  Clássica          54.674571           5NN           33.077598        EMC
# 47  Clássica          54.674571           5NN           33.077598        EMC
# 48  Clássica          54.674571           5NN           33.077598        EMC
# 49  Clássica          54.674571           5NN           33.077598        EMC
#
#     Conjunto de dados   Acurácia         F1  Index da bag  Orçamento  \
# 0                1043  77.108434  76.178276             0          0
# 1                1043  77.108434  75.493640             0          1
# 2                1043  77.546550  75.792694             0          2
# 3                1043  77.984666  76.794328             0          3
# 4                1043  77.108434  75.493640             0          4
# 5                1043  77.546550  75.906799             0          5
# 6                1043  78.532311  76.827698             0          6
# 7                1043  78.860898  76.299440             0          7
# 8                1043  77.108434  75.493640             0          8
# 9                1043  78.422782  77.398117             0          9
# 10               1043  77.108434  75.493640             0         10
# 11               1043  77.108434  75.493640             0         11
# 12               1043  77.656079  75.704217             0         12
# 13               1043  78.532311  75.965143             0         13
# 14               1043  77.217963  74.841634             0         14
# 15               1043  77.108434  75.493640             0         15
# 16               1043  78.094195  76.982609             0         16
# 17               1043  77.984666  76.207902             0         17
# 18               1043  78.313253  76.647128             0         18
# 19               1043  78.094195  77.102722             1          0
# 20               1043  78.094195  76.466900             1          1
# 21               1043  78.532311  77.347458             1          2
# 22               1043  78.641840  77.718047             1          3
# 23               1043  78.313253  76.810143             1          4
# 24               1043  78.094195  76.466900             1          5
# 25               1043  78.094195  76.466900             1          6
# 26               1043  78.094195  76.466900             1          7
# 27               1043  78.094195  76.466900             1          8
# 28               1043  79.299014  77.628326             1          9
# 29               1043  78.094195  76.466900             1         10
# 30               1043  78.422782  76.140214             1         11
# 31               1043  79.737130  77.939537             1         12
# 32               1043  78.751369  77.530342             1         13
# 33               1043  78.094195  76.466900             1         14
# 34               1043  78.094195  76.466900             1         15
# 35               1043  78.094195  76.466900             1         16
# 36               1043  78.094195  76.466900             1         17
# 37               1043  78.094195  76.466900             1         18
# 38               1043  78.532311  78.059926             2          0
# 39               1043  78.532311  76.991348             2          1
# 40               1043  79.189485  77.537054             2          2
# 41               1043  78.532311  76.991348             2          3
# 42               1043  78.532311  76.991348             2          4
# 43               1043  78.532311  76.991348             2          5
# 44               1043  78.532311  76.991348             2          6
# 45               1043  78.532311  76.991348             2          7
# 46               1043  78.532311  76.991348             2          8
# 47               1043  78.641840  76.918114             2          9
# 48               1043  78.532311  76.991348             2         10
# 49               1043  78.751369  76.407929             2         11
#
#        Abordagem
# 0   non agnostic
# 1   non agnostic
# 2   non agnostic
# 3   non agnostic
# 4   non agnostic
# 5   non agnostic
# 6   non agnostic
# 7   non agnostic
# 8   non agnostic
# 9   non agnostic
# 10  non agnostic
# 11  non agnostic
# 12  non agnostic
# 13  non agnostic
# 14  non agnostic
# 15  non agnostic
# 16  non agnostic
# 17  non agnostic
# 18  non agnostic
# 19  non agnostic
# 20  non agnostic
# 21  non agnostic
# 22  non agnostic
# 23  non agnostic
# 24  non agnostic
# 25  non agnostic
# 26  non agnostic
# 27  non agnostic
# 28  non agnostic
# 29  non agnostic
# 30  non agnostic
# 31  non agnostic
# 32  non agnostic
# 33  non agnostic
# 34  non agnostic
# 35  non agnostic
# 36  non agnostic
# 37  non agnostic
# 38  non agnostic
# 39  non agnostic
# 40  non agnostic
# 41  non agnostic
# 42  non agnostic
# 43  non agnostic
# 44  non agnostic
# 45  non agnostic
# 46  non agnostic
# 47  non agnostic
# 48  non agnostic
# 49  non agnostic

# %% [markdown]
# ### Groupby por dataset

# %%
df = df_all[:]

# %%
# explode pelas colunas accuracy_history e f1_history
df = df.set_index(['package','time_elapsed','classifier','sample_size','strategy','dataset']).apply(pd.Series.explode).reset_index()

# explode retorna coluna como object, logo é necessário transformar em número
df['f1_history'] = pd.to_numeric(df['f1_history'])
df['accuracy_history'] = pd.to_numeric(df['accuracy_history'])

# %%
df \
.drop(['id_bag','cost'], axis=1) \
.groupby(['dataset','package','strategy', 'classifier']) \
.mean() \
.sort_values("f1_history", ascending = False).reset_index() \
.rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
# Out:
#       Conjunto de dados    Pacote Estratégia Classificador  Tempo de execução  \
# 0                  1526  Clássica        EMC          C4.5           1.699880
# 1                  1526  Clássica        QBC            RF        1112.866467
# 2                  1526  Clássica        QBC          C4.5          19.400717
# 3                  1526  Clássica        EMC            RF          71.136009
# 4                  1526  Proposta         N1          C4.5         172.304386
# ...                 ...       ...        ...           ...                ...
# 2835               1475  Proposta        LSC            NB         156.435788
# 2836               1475  Proposta         F3            NB         174.516157
# 2837               1475  Proposta          U            NB         149.874417
# 2838               1475  Clássica        QBC            NB         135.219860
# 2839               1475  Proposta         HU            NB         151.576080
#
#       Tamanho da amostra   Acurácia         F1
# 0              41.015396  99.962406  99.958443
# 1             233.907625  99.967226  99.955122
# 2             233.907625  99.958550  99.954586
# 3              58.027859  99.919028  99.904578
# 4              99.908341  99.935415  99.879422
# ...                  ...        ...        ...
# 2835           99.734369  18.971448  17.162732
# 2836           99.734369  18.823529  16.386698
# 2837           99.734369  17.874097  15.126285
# 2838          233.899967  16.097351  12.973876
# 2839           99.734369  16.337289  12.741773
#
# [2840 rows x 8 columns]

# %%
df_all[df_all.strategy != 'Expected Error Reduction'] \
.drop(['dataset', 'id_bag','cost'], axis=1) \
.groupby(['package','strategy', 'classifier']) \
.mean() \
.sort_values("f1_history", ascending = False) \
.reset_index() \
.rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
# Out:
#       Pacote Estratégia Classificador  Tempo de execução  Tamanho da amostra  \
# 0   Proposta        LSC            RF         212.885132           99.375485
# 1   Proposta          U            RF         217.508133           99.375485
# 2   Proposta         HU            RF         217.484370           99.375485
# 3   Clássica        QBC            RF        1013.654418          234.046584
# 4   Proposta          H            RF         226.954043           99.375485
# 5   Proposta         N1            RF         206.383301           99.375485
# 6   Proposta         F3            RF         190.814581           99.375485
# 7   Clássica         US            RF          25.073215           38.211180
# 8   Proposta          U          C4.5         151.950588           99.375485
# 9   Proposta        LSC          C4.5         156.678156           99.375485
# 10  Clássica        EMC            RF          67.128868           69.066329
# 11  Proposta         HU          C4.5         154.683280           99.375485
# 12  Clássica        QBC          C4.5          63.199737          234.046584
# 13  Proposta         F3          C4.5         163.846029           99.375485
# 14  Proposta          H          C4.5         152.273124           99.375485
# 15  Proposta         N1          C4.5         156.092927           99.375485
# 16  Baseline         RS            RF          51.097891          102.328347
# 17  Proposta        LSC           5NN         196.149669           99.375485
# 18  Proposta          U           5NN         193.756813           99.375485
# 19  Proposta         HU           5NN         193.288579           99.375485
# 20  Clássica        EMC          C4.5           6.356661           66.511629
# 21  Proposta          H           5NN         193.886244           99.375485
# 22  Proposta         N1           5NN         194.393032           99.375485
# 23  Proposta         F3           5NN         181.969905           99.375485
# 24  Clássica         US           5NN          23.286708           32.837559
# 25  Clássica        EMC           5NN          45.749576           63.521212
# 26  Clássica         US          C4.5           1.767054            8.014257
# 27  Clássica        QBC           5NN         630.768146          234.046584
# 28  Baseline         RS          C4.5           3.329291          102.328347
# 29  Clássica        EMC            NB           6.391491           53.346052
# 30  Proposta        LSC            NB         198.814722           99.375485
# 31  Baseline         RS           5NN          24.507026          102.328347
# 32  Proposta         N1            NB         152.868073           99.375485
# 33  Proposta         HU            NB         153.981104           99.375485
# 34  Clássica         US            NB           2.342620           21.058516
# 35  Proposta          U            NB         153.433893           99.375485
# 36  Proposta          H            NB         156.850378           99.375485
# 37  Clássica        QBC            NB          70.529154          234.046584
# 38  Baseline         RS            NB           3.744883          102.328347
# 39  Proposta         F3            NB         163.810857           99.375485
#
#      Acurácia         F1
# 0   83.160469  85.374693
# 1   82.999354  85.126088
# 2   82.984574  85.046554
# 3   85.298726  84.477687
# 4   82.314360  83.993075
# 5   82.188875  83.927306
# 6   82.224548  83.838969
# 7   83.261933  82.314711
# 8   77.898801  81.325051
# 9   77.818729  81.311654
# 10  82.363427  81.284216
# 11  77.798982  81.232995
# 12  80.440316  80.292086
# 13  76.920138  79.970091
# 14  76.912839  79.957615
# 15  76.804261  79.883094
# 16  79.681969  78.423651
# 17  77.542133  77.545842
# 18  77.474155  77.401129
# 19  77.472505  77.333835
# 20  77.399378  77.321503
# 21  76.806144  76.562665
# 22  76.800811  76.488648
# 23  76.607547  76.387050
# 24  77.392213  76.264371
# 25  77.182222  75.814788
# 26  75.116197  75.149391
# 27  75.017475  74.357617
# 28  73.774623  73.730612
# 29  74.158120  73.566650
# 30  73.245911  73.080518
# 31  74.488587  72.828261
# 32  72.897449  72.639375
# 33  72.722554  72.543387
# 34  73.229631  72.519092
# 35  72.775352  72.493219
# 36  72.534405  72.250975
# 37  72.811177  72.195148
# 38  72.305809  71.810609
# 39  71.879336  71.579243

# %%
df_all \
.drop(['id_bag','cost'], axis=1) \
.groupby(['dataset','package','strategy', 'classifier']) \
.std() \
.sort_values("f1_history", ascending = False) \
.reset_index() \
.rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
# Out:
#       Conjunto de dados    Pacote Estratégia Classificador  Tempo de execução  \
# 0                  1050  Proposta         F3            NB           0.213075
# 1                  1050  Proposta         HU            NB           2.386096
# 2                  1050  Proposta          H            NB           1.048675
# 3                  1050  Clássica         US            NB           0.089361
# 4                  1050  Proposta        LSC            NB           0.825930
# ...                 ...       ...        ...           ...                ...
# 2835               1069  Proposta        LSC           5NN           4.127885
# 2836               1069  Proposta          H           5NN           2.260617
# 2837               1069  Proposta         HU           5NN           4.141649
# 2838               1069  Proposta         N1           5NN           1.669558
# 2839               1069  Proposta          U           5NN          12.552600
#
#       Tamanho da amostra   Acurácia         F1
# 0               0.000000  30.733091  34.562637
# 1               0.000000  30.292524  34.102923
# 2               0.000000  27.901690  32.279258
# 3               4.064957  28.882721  31.800914
# 4               0.000000  28.648954  31.784806
# ...                  ...        ...        ...
# 2835            0.000000   0.000000   0.000000
# 2836            0.000000   0.000000   0.000000
# 2837            0.000000   0.000000   0.000000
# 2838            0.000000   0.000000   0.000000
# 2839            0.000000   0.000000   0.000000
#
# [2840 rows x 8 columns]

# %% [markdown]
# ## Boxplot

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.boxplot(data=df_all, x="accuracy_history", y="strategy", orient="h", order = ["QBC", "H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"]) \
.set(xlabel='Acurácia (%)', ylabel='Estratégia', title = "Acurácia por estratégia")

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.boxplot(data=df_all, x="f1_history", y="strategy", orient="h", order = ["QBC", "H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"]) \
.set(xlabel='F1 Score (%)', ylabel='Estratégia', title = "F1 Score por estratégia")

# %% [markdown]
# ## Testes (lineplot)

# %% [raw]
# # Plot our performance over time.
# fig, ax = plt.subplots(figsize=(8.5, 6), dpi=130)
#
#
# k_legend = []
# for idx,pht in enumerate(performance_history_total):
#     ax.plot(pht)
#     ax.scatter(range(len(pht)), pht, s=13)
#     k_legend.append('k = ' + str(k_neighbor[idx]))
#
# ax.xaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=5, integer=True))
# ax.yaxis.set_major_locator(mpl.ticker.MaxNLocator(nbins=10))
# ax.yaxis.set_major_formatter(mpl.ticker.PercentFormatter(xmax=1))
#
# ax.set_ylim(bottom=0, top=1)
# ax.grid(True)
#
# ax.set_title("Incremental classification accuracy with {n_queries} queries".format(n_queries = N_QUERIES))
# ax.set_xlabel('Query iteration')
# ax.set_ylabel('Classification Accuracy')
# ax.legend(k_legend, loc='lower right')
#
# plt.show()

# %%
# Plot the responses for different events and regions
data = df_all[(df_all.classifier == "RF")].rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
sns.set(rc={'figure.figsize':(20,10)})
_ = sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", data = data).set(xlabel='Acurácia', ylabel='Estratégia', xticks = range(1,19), title = "Random Forest")

# %%
# Plot the responses for different events and regions
data = df_all[(df_all.classifier == "RF")].rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
sns.set(rc={'figure.figsize':(20,10)})
_ = sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", ci=None, data = data, size=10).set(xlabel='Orçamento', ylabel='Acurácia (%)', xticks = range(1,19), title = "Random Forest")

# %%
# Plot the responses for different events and regions
data = df_all[(df_all.classifier == "NB")].rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
sns.set(rc={'figure.figsize':(20,10)})
_ = sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", data = data).set(xlabel='Orçamento', ylabel='Acurácia (%)', xticks = range(1,19), title = "Naive Bayes")

# %%
# Plot the responses for different events and regions
data = df_all[(df_all.classifier == "5NN")].rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
sns.set(rc={'figure.figsize':(20,10)})
_ = sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", data = data).set(xlabel='Acurácia', ylabel='Estratégia', xticks = range(1,19), title = "5 vizinhos mais próximos")

# %%
# Plot the responses for different events and regions
data = df_all[(df_all.classifier == "C4.5")].rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
sns.set(rc={'figure.figsize':(20,10)})
_ = sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", data = data).set(xlabel='Acurácia', ylabel='Estratégia', xticks = range(1,19), title = "Árvore de decisão (C4.5)")
sns.set_style('darkgrid', {'legend.frameon':True})

# %% [raw]
# data = df_all[(df_all.classifier == "RF")].rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
# fig, axs = plt.subplots(2, 2, figsize=(20, 10))
#
# sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", data = data, ax=axs[0, 0], legend = False).set(xlabel='', ylabel='Acurácia (%)', xticks = range(1,19), title = "Random Forest")
# sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", ci=None, data = data, ax=axs[0, 1], legend = False).set(xlabel='', ylabel='', xticks = range(1,19), title = "Random Forest")
# sns.lineplot(x="Orçamento", y="F1", hue="Estratégia", style="Pacote", data = data, ax=axs[1, 0], legend = False).set(xlabel='Orçamento', ylabel='F1 (%)', xticks = range(1,19), title = "")
# sns.lineplot(x="Orçamento", y="F1", hue="Estratégia", style="Pacote", ci=None, data = data, ax=axs[1, 1], legend = False).set(xlabel='Orçamento', ylabel='', xticks = range(1,19), title = "")
# #sns.lineplot(x="Orçamento", y="Acurácia", hue="Estratégia", style="Pacote", ci=None, data = data, size=10, ax=axs[0, 2]).set(xlabel='', ylabel='', title = "")
# #sns.lineplot(x="Orçamento", y="F1", hue="Estratégia", style="Pacote", ci=None, data = data, size=10, ax=axs[1, 2]).set(xlabel='', ylabel='', title = "")
#
# plt.show()

# %% [raw]
# fig, axs = plt.subplots(2, 2, figsize=(20, 10))
#
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "RF")], ax=axs[0, 0], legend = False).set(xlabel='', ylabel='Acurácia', xticks = range(1,19),  title = "Random Forest")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "5NN")], ax=axs[0, 1], legend = False).set(xlabel='', ylabel='', xticks = range(1,19), title = "5 vizinhos mais próximos")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "NB")], ax=axs[1, 0], legend = False).set(xlabel='Orçamento', ylabel='Acurácia', xticks = range(1,19),  title = "Naive Bayes")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "C4.5")], ax=axs[1, 1], legend = False).set(xlabel='Orçamento', ylabel='', xticks = range(1,19),  title = "Árvore de decisão (C4.5)")
#
# plt.show()

# %% [raw]
# fig, axs = plt.subplots(4, 1, figsize=(20, 50))
#
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", ci = False, data=df_all[(df_all.classifier == "RF")], ax=axs[0]).set(xlabel='', ylabel='Acurácia', xticks = range(0,19),  title = "Random Forest")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", ci = False, data=df_all[(df_all.classifier == "5NN")], ax=axs[1]).set(xlabel='', ylabel='', xticks = range(0,19), title = "5 vizinhos mais próximos")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", ci = False, data=df_all[(df_all.classifier == "NB")], ax=axs[2]).set(xlabel='Orçamento', ylabel='Acurácia', xticks = range(0,19),  title = "Naive Bayes")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", ci = False, data=df_all[(df_all.classifier == "C4.5")], ax=axs[3]).set(xlabel='Orçamento', ylabel='', xticks = range(0,19),  title = "Árvore de decisão (C4.5)")
#
# plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", ci = False, data=df_all).set(xlabel='', ylabel='Acurácia', xticks = range(0,19),  title = "Acurácia geral (%) por custo")
plt.show()

# %% [raw]
# fig, axs = plt.subplots(2, 2, figsize=(20, 10))
#
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "RF")], size=10, ax=axs[0, 0], legend = False).set(xlabel='', ylabel='Acurácia', xticks = range(1,19), yticks = range(65,87,5), title = "Random Forest")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "5NN")], size=10, ax=axs[0, 1], legend = False).set(xlabel='', ylabel='', xticks = range(1,19), yticks = range(65,87,5), title = "5 vizinhos mais próximos")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "NB")], size=10, ax=axs[1, 0], legend = False).set(xlabel='Orçamento', ylabel='Acurácia', xticks = range(1,19), yticks = range(65,87,5), title = "Naive Bayes")
# sns.lineplot(x="cost", y="accuracy_history", hue="strategy", style="package", data=df_all[(df_all.classifier == "C4.5")], size=10, ax=axs[1, 1], legend = False).set(xlabel='Orçamento', ylabel='', xticks = range(1,19), yticks = range(65,87,5), title = "Árvore de decisão (C4.5)")
#
# plt.show()

# %% [raw]
# fig, axs = plt.subplots(2, 2, figsize=(20, 10))
#
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "RF")], ax=axs[0, 0]).set(xlabel='', ylabel='Acurácia', xticks = range(1,19), yticks = range(72,87,5), title = "Random Forest")
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "5NN")], ax=axs[0, 1]).set(xlabel='', ylabel='', xticks = range(1,19), yticks = range(72,87,5), title = "5 vizinhos mais próximos")
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "NB")], ax=axs[1, 0]).set(xlabel='Orçamento', ylabel='Acurácia', xticks = range(1,19), yticks = range(72,87,5), title = "Naive Bayes")
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "C4.5")], ax=axs[1, 1]).set(xlabel='Orçamento', ylabel='', xticks = range(1,19), yticks = range(72,87,5), title = "Árvore de decisão (C4.5)")
#
# plt.show()

# %% [raw]
# fig, axs = plt.subplots(1, 4, figsize=(20, 5))
#
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "RF")], size=10, ax=axs[0], legend = False).set(xlabel='Orçamento', ylabel='Acurácia (%)', xticks = [0,18], yticks = [72,87], title = "Random Forest")
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "5NN")], size=10, ax=axs[1], legend = False).set(xlabel='Orçamento', ylabel='', xticks = [0,18], yticks = [72,87], title = "5 vizinhos mais próximos")
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "C4.5")], size=10, ax=axs[2], legend = False).set(xlabel='Orçamento', ylabel='', xticks = [0,18], yticks = [72,87], title = "Árvore de decisão (C4.5)")
# sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "NB")], size=10, ax=axs[3], legend = False).set(xlabel='Orçamento', ylabel='', xticks = [0,18], yticks = [72,87], title = "Naive Bayes")
#
# plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "RF")]).set(xlabel='Orçamento', ylabel='Acurácia (%)', xticks = range(0,19), yticks = range(72,87,3), title = "Random Forest")

plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "RF")]).set(xlabel='Orçamento', ylabel='F1 Score (%)', xticks = range(0,19), yticks = range(72,87,3), title = "Random Forest")

plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "5NN")]).set(xlabel='Orçamento', ylabel='Acurácia (%)', xticks = range(0,19), yticks = range(72,87,3), title = "5 vizinhos mais próximos")

plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "5NN")]).set(xlabel='Orçamento', ylabel='F1 Score (%)', xticks = range(0,19), yticks = range(72,87,3), title = "5 vizinhos mais próximos")

plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "C4.5")]).set(xlabel='Orçamento', ylabel='Acurácia (%)', xticks = range(0,19), yticks = range(72,87,3), title = "Árvore de decisão (C4.5)")

plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "C4.5")]).set(xlabel='Orçamento', ylabel='F1 Score (%)', xticks = range(0,19), yticks = range(72,87,3), title = "Árvore de decisão (C4.5)")

plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="accuracy_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "NB")]).set(xlabel='Orçamento', ylabel='Acurácia (%)', xticks = range(0,19), yticks = range(72,87,3), title = "Naive Bayes")

plt.show()

# %%
fig, axs = plt.subplots(figsize=(20, 10))

sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "NB")]).set(xlabel='Orçamento', ylabel='F1 Score (%)', xticks = range(0,19), yticks = range(72,87,3), title = "Naive Bayes")

plt.show()

# %%
import os
len(os.listdir("../datasets"))

# %% [raw]
# fig, axs = plt.subplots(1, 4, figsize=(20, 5))
#
# sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "RF")], size=10, ax=axs[0], legend = False).set(xlabel='Orçamento', ylabel='F1 Score (%)', xticks = [0,18], yticks = [72,87], title = "Random Forest")
# sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "5NN")], size=10, ax=axs[1], legend = False).set(xlabel='Orçamento', ylabel='', xticks = [0,18], yticks = [72,87], title = "5 vizinhos mais próximos")
# sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "C4.5")], size=10, ax=axs[2], legend = False).set(xlabel='Orçamento', ylabel='', xticks = [0,18], yticks = [72,87], title = "Árvore de decisão (C4.5)")
# sns.lineplot(x="cost", y="f1_history", ci = False, hue="strategy", style="package", data=df_all[(df_all.classifier == "NB")], size=10, ax=axs[3], legend = False).set(xlabel='Orçamento', ylabel='', xticks = [0,18], yticks = [72,87], title = "Naive Bayes")
#
# plt.show()

# %% [raw]
# df_filter = df_all[:]
# df_filter = df_filter[(df_filter.package == 'baseline') | (df_filter.package == 'Pyhard') | ((df_filter.package == 'modAL') & (df_filter.cost == 0)) | ((df_filter.package == 'modAL') & (df_filter.cost == 10))]
# df_filter[df_filter.cost == 10] = 1

# %% [markdown]
# ## Heatmap

# %%
df_all.groupby(['strategy','classifier']).std() \
.reset_index() \
.rename(columns={"package": "Pacote", "time_elapsed": "Tempo de execução", "classifier": "Classificador", "sample_size": "Tamanho da amostra", "strategy": "Estratégia","dataset": "Conjunto de dados", "accuracy_history": "Acurácia", "f1_history": "F1", "id_bag": "Index da bag", "cost": "Orçamento", "approach":"Abordagem"})
# Out:
#    Estratégia Classificador  Tempo de execução  Tamanho da amostra  \
# 0         EMC           5NN          38.955154           34.640283
# 1         EMC          C4.5          12.509034           28.034936
# 2         EMC            NB          12.009323           28.333313
# 3         EMC            RF          13.220681           29.424631
# 4          F3           5NN          93.528777            0.919199
# 5          F3          C4.5          92.482128            0.919199
# 6          F3            NB          92.476513            0.919199
# 7          F3            RF          89.741115            0.919199
# 8           H           5NN          70.994059            0.919199
# 9           H          C4.5          48.238794            0.919199
# 10          H            NB          49.222598            0.919199
# 11          H            RF         106.355381            0.919199
# 12         HU           5NN          66.273529            0.919199
# 13         HU          C4.5          47.456639            0.919199
# 14         HU            NB          45.285002            0.919199
# 15         HU            RF          89.950777            0.919199
# 16        LSC           5NN          68.614163            0.919199
# 17        LSC          C4.5          50.415541            0.919199
# 18        LSC            NB         362.423198            0.919199
# 19        LSC            RF          71.621603            0.919199
# 20         N1           5NN          66.619865            0.919199
# 21         N1          C4.5          50.935238            0.919199
# 22         N1            NB          44.622188            0.919199
# 23         N1            RF          69.231623            0.919199
# 24        QBC           5NN         520.580646            0.604155
# 25        QBC          C4.5         116.254998            0.604155
# 26        QBC            NB          98.915087            0.604155
# 27        QBC            RF         144.755283            0.604155
# 28         RS           5NN          20.618408            3.546066
# 29         RS          C4.5           6.135503            3.546066
# 30         RS            NB           5.669334            3.546066
# 31         RS            RF           7.499156            3.546066
# 32          U           5NN          68.079943            0.919199
# 33          U          C4.5          47.576573            0.919199
# 34          U            NB          46.668320            0.919199
# 35          U            RF          93.706457            0.919199
# 36         US           5NN          19.826471           20.949082
# 37         US          C4.5           3.264979            0.459911
# 38         US            NB           4.198651           20.436593
# 39         US            RF           8.544668           20.983430
#
#     Conjunto de dados   Acurácia         F1  Index da bag  Orçamento
# 0         6604.897544  17.949095  18.125718      1.414318   5.477632
# 1         6604.897544  17.026839  17.079578      1.414318   5.477632
# 2         6604.897544  19.376888  20.226320      1.414318   5.477632
# 3         6604.897544  15.851595  16.186431      1.414318   5.477632
# 4         6604.897544  18.912215  18.171719      1.414318   5.477632
# 5         6604.897544  17.602880  15.724037      1.414318   5.477632
# 6         6604.897544  20.721242  21.621371      1.414318   5.477632
# 7         6604.897544  16.131786  14.294513      1.414318   5.477632
# 8         6604.897544  18.465674  17.822642      1.414318   5.477632
# 9         6604.897544  17.067213  15.197411      1.414318   5.477632
# 10        6604.897544  20.337570  21.185626      1.414318   5.477632
# 11        6604.897544  15.778383  14.031391      1.414318   5.477632
# 12        6604.897544  18.521143  18.017129      1.414318   5.477632
# 13        6604.897544  17.351407  15.541572      1.414318   5.477632
# 14        6604.897544  20.453754  21.192411      1.414318   5.477632
# 15        6604.897544  16.011449  14.266574      1.414318   5.477632
# 16        6604.897544  18.406529  17.923709      1.414318   5.477632
# 17        6604.897544  17.393118  15.495885      1.414318   5.477632
# 18        6604.897544  20.139683  20.875411      1.414318   5.477632
# 19        6604.897544  16.012611  14.277332      1.414318   5.477632
# 20        6604.897544  18.432155  17.785718      1.414318   5.477632
# 21        6604.897544  17.181945  15.350123      1.414318   5.477632
# 22        6604.897544  19.856811  20.644687      1.414318   5.477632
# 23        6604.897544  15.972074  14.044439      1.414318   5.477632
# 24        6604.897544  18.369855  18.405436      1.414318   5.477632
# 25        6604.897544  16.434529  16.435217      1.414318   5.477632
# 26        6604.897544  19.630338  20.807162      1.414318   5.477632
# 27        6604.897544  15.241070  15.540626      1.414318   5.477632
# 28        6604.897544  18.843007  19.072275      1.414318   5.477632
# 29        6604.897544  18.245390  18.309228      1.414318   5.477632
# 30        6604.897544  20.046699  20.794813      1.414318   5.477632
# 31        6604.897544  16.813940  17.079877      1.414318   5.477632
# 32        6604.897544  18.427338  17.985994      1.414318   5.477632
# 33        6604.897544  17.426568  15.535717      1.414318   5.477632
# 34        6604.897544  20.383412  21.220231      1.414318   5.477632
# 35        6604.897544  16.011037  14.173994      1.414318   5.477632
# 36        6604.897544  17.861231  17.848122      1.414318   5.477632
# 37        6604.897544  17.665424  17.780031      1.414318   5.477632
# 38        6604.897544  19.821755  20.903183      1.414318   5.477632
# 39        6604.897544  15.466170  15.740885      1.414318   5.477632

# %% [raw]
# fig, axs = plt.subplots(2, 2, figsize=(20, 10))
#
# X = pd.pivot_table(df_all, values='accuracy_history', index=['strategy'], columns='classifier')
# Y = pd.pivot_table(df_all.groupby(['strategy','classifier']).mean(), values='accuracy_history', index=['strategy'], columns='classifier')
# Z = pd.pivot_table(df_all.groupby(['strategy','classifier']).std(), values='accuracy_history', index=['strategy'], columns='classifier')
#
# R = Y[:]
# for col in Z.columns:
#     R[col] = Y[col].round(3).astype(str) + " ± " + Z[col].round(3).astype(str)
#
# sns.set(rc={'figure.figsize':(15,5)})
# sns.heatmap(X, annot=False, ax=axs[0, 1]).set(xlabel='Classificador', ylabel='Estratégia', title = "Acurácia")
# sns.heatmap(X, annot=R, fmt="", cbar=False, ax=axs[0, 1]).set(xlabel='Classificador', ylabel='Estratégia', title = "Acurácia")
# #sns.heatmap(X, annot=Z, annot_kws={'va':'top'}, fmt=".2f", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "F1")
#
# X = pd.pivot_table(df_all, values='f1_history', index=['strategy'], columns='classifier')
# Y = pd.pivot_table(df_all.groupby(['strategy','classifier']).mean(), values='f1_history', index=['strategy'], columns='classifier')
# Z = pd.pivot_table(df_all.groupby(['strategy','classifier']).std(), values='f1_history', index=['strategy'], columns='classifier')
#
# R = Y[:]
# for col in Z.columns:
#     R[col] = Y[col].round(3).astype(str) + " ± " + Z[col].round(3).astype(str)
#
# sns.set(rc={'figure.figsize':(15,5)})
# sns.heatmap(X, annot=False, ax=axs[0, 0]).set(xlabel='Classificador', ylabel='Estratégia', title = "F1 Score")
# sns.heatmap(X, annot=R, fmt="", cbar=False, ax=axs[0, 0]).set(xlabel='Classificador', ylabel='Estratégia', title = "F1 Score")
# #sns.heatmap(X, annot=Z, annot_kws={'va':'top'}, fmt=".2f", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "F1")
#
#
# plt.show()

# %%
X = pd.pivot_table(df_all, values='accuracy_history', index=['strategy'], columns='classifier')
Y = pd.pivot_table(df_all.groupby(['strategy','classifier']).mean(), values='accuracy_history', index=['strategy'], columns='classifier')
Z = pd.pivot_table(df_all.groupby(['strategy','classifier']).std(), values='accuracy_history', index=['strategy'], columns='classifier')

R = Y[:]
for col in Z.columns:
    R[col] = Y[col].round(3).astype(str) + " ± " + Z[col].round(3).astype(str)

sns.set(rc={'figure.figsize':(15,5)})
sns.heatmap(X, annot=False).set(xlabel='Classificador', ylabel='Estratégia', title = "Acurácia (%)")
sns.heatmap(X, annot=R, fmt="", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "Acurácia (%)")
#sns.heatmap(X, annot=Z, annot_kws={'va':'top'}, fmt=".2f", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "F1")
# Out:
# [Text(0.5, 21.5, 'Classificador'),
#  Text(111.5, 0.5, 'Estratégia'),
#  Text(0.5, 1.0, 'Acurácia (%)')]

# %%
X = pd.pivot_table(df_all, values='accuracy_history', index=['strategy'], columns='classifier')
Y = pd.pivot_table(df_all.groupby(['strategy','classifier']).mean(), values='accuracy_history', index=['strategy'], columns='classifier')
Z = pd.pivot_table(df_all.groupby(['strategy','classifier']).std(), values='accuracy_history', index=['strategy'], columns='classifier')

R = Y[:]
for col in Z.columns:
    R[col] = Y[col].round(3).astype(str) + " ± " + Z[col].round(3).astype(str)

X = X.reindex(columns= ["RF", "C4.5", "5NN", "NB"],index= ["QBC", "H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"])
R = R.reindex(columns= ["RF", "C4.5", "5NN", "NB"],index= ["QBC","H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"])  

sns.set(rc={'figure.figsize':(15,5)})
sns.heatmap(X, annot=False).set(xlabel='Classificador', ylabel='Estratégia', title = "Acurácia (%)")
sns.heatmap(X, annot=R, fmt="", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "Acurácia (%)")
#sns.heatmap(X, annot=Z, annot_kws={'va':'top'}, fmt=".2f", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "F1")
# Out:
# [Text(0.5, 21.5, 'Classificador'),
#  Text(111.5, 0.5, 'Estratégia'),
#  Text(0.5, 1.0, 'Acurácia (%)')]

# %%
X = pd.pivot_table(df_all, values='f1_history', index=['strategy'], columns='classifier')
Y = pd.pivot_table(df_all.groupby(['strategy','classifier']).mean(), values='f1_history', index=['strategy'], columns='classifier')
Z = pd.pivot_table(df_all.groupby(['strategy','classifier']).std(), values='f1_history', index=['strategy'], columns='classifier')

R = Y[:]
for col in Z.columns:
    R[col] = Y[col].round(3).astype(str) + " ± " + Z[col].round(3).astype(str)

X = X.reindex(columns= ["RF", "C4.5", "5NN", "NB"],index= ["QBC", "H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"])  
R = R.reindex(columns= ["RF", "C4.5", "5NN", "NB"],index= ["QBC", "H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"])
    
sns.set(rc={'figure.figsize':(15,5)})
sns.heatmap(X, annot=False).set(xlabel='Classificador', ylabel='Estratégia', title = "F1 Score (%)")
sns.heatmap(X, annot=R, fmt="", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "F1 Score (%)")
#sns.heatmap(X, annot=Z, annot_kws={'va':'top'}, fmt=".2f", cbar=False).set(xlabel='Classificador', ylabel='Estratégia', title = "F1")
# Out:
# [Text(0.5, 21.5, 'Classificador'),
#  Text(111.5, 0.5, 'Estratégia'),
#  Text(0.5, 1.0, 'F1 Score (%)')]

# %%
sns.set(rc={'figure.figsize':(15.7,25.27)})
heatmap_data = pd.pivot_table(df_all, values='accuracy_history', index=['dataset'], columns='strategy')


heatmap_data = heatmap_data.reindex(columns= ["QBC", "H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"])

_ = sns.heatmap(heatmap_data, annot=True).set(xlabel='Estratégia', ylabel='Conjunto de dados', title = "Acurácia (%) dos conjuntos de dados por estratégia")

# %%
sns.set(rc={'figure.figsize':(15.7,25.27)})
heatmap_data = pd.pivot_table(df_all, values='f1_history', index=['dataset'], columns='strategy')

heatmap_data = heatmap_data.reindex(columns= ["QBC", "H", "U", "HU", "LSC", "N1", "F3", "US", "EMC", "RS"])

_ = sns.heatmap(heatmap_data, annot=True).set(xlabel='Estratégia', ylabel='Conjunto de dados', title = "F1 Score (%) dos conjuntos de dados por estratégia")

# %%
df = df_all.groupby(['dataset','strategy']).mean()
df["rank"] = df.groupby("dataset")["accuracy_history"].rank(ascending = False)
#df.groupby('strategy').mean()
df.head(30)
# Out:
#                   time_elapsed  sample_size  accuracy_history  f1_history  \
# dataset strategy
# 3       EMC          31.239417    83.823529         86.080181   84.808705
#         F3          150.588611    99.413146         85.406250   83.994441
#         H           147.618239    99.413146         84.909951   83.570268
#         HU          153.659396    99.413146         85.096217   83.034487
#         LSC         149.960748    99.413146         85.975329   84.043158
#         N1          150.108629    99.413146         84.996711   83.832875
#         QBC         442.423452   233.729662         84.958470   82.930369
#         RS           19.762346    99.217772         83.442023   82.221734
#         U           148.631239    99.413146         84.511924   82.187412
#         US           10.636359    16.739675         85.831826   84.304707
# 12      EMC          37.610796    90.500000         87.648026   87.588007
#         F3          602.420195   100.000000         86.652632   87.081924
#         H           226.819421   100.000000         87.128289   87.562777
#         HU          229.642797   100.000000         88.790789   90.398555
#         LSC         227.213427   100.000000         89.167763   90.823100
#         N1          231.407608   100.000000         87.284868   87.093806
#         QBC         468.910327   234.000000         89.661842   89.577087
#         RS           22.108426   107.000000         83.292105   83.243169
#         U           226.959050   100.000000         88.971711   90.614158
#         US           13.500248    22.750000         86.684868   86.613289
# 14      EMC          27.035792    80.000000         73.784868   73.533520
#         F3          276.680035   100.000000         73.812500   75.300844
#         H           148.008855   100.000000         74.225000   75.673395
#         HU          147.797698   100.000000         73.683553   75.274544
#         LSC         145.688337   100.000000         73.971711   75.507170
#         N1          146.511306   100.000000         74.167105   75.583157
#         QBC         363.849959   234.000000         76.259211   76.230454
#         RS           18.038293   107.000000         68.933553   68.799778
#         U           147.887032   100.000000         73.817105   75.567919
#         US           11.839118    28.500000         72.961842   72.691573
#
#                   id_bag  cost  rank
# dataset strategy
# 3       EMC            2     9   1.0
#         F3             2     9   4.0
#         H              2     9   8.0
#         HU             2     9   5.0
#         LSC            2     9   2.0
#         N1             2     9   6.0
#         QBC            2     9   7.0
#         RS             2     9  10.0
#         U              2     9   9.0
#         US             2     9   3.0
# 12      EMC            2     9   5.0
#         F3             2     9   9.0
#         H              2     9   7.0
#         HU             2     9   4.0
#         LSC            2     9   2.0
#         N1             2     9   6.0
#         QBC            2     9   1.0
#         RS             2     9  10.0
#         U              2     9   3.0
#         US             2     9   8.0
# 14      EMC            2     9   7.0
#         F3             2     9   6.0
#         H              2     9   2.0
#         HU             2     9   8.0
#         LSC            2     9   4.0
#         N1             2     9   3.0
#         QBC            2     9   1.0
#         RS             2     9  10.0
#         U              2     9   5.0
#         US             2     9   9.0

# %%
df.groupby('strategy').mean().rank(method = 'first',ascending=True).sort_values(by='rank', ascending=True)['rank']
# Out:
# strategy
# LSC     1.0
# EMC     2.0
# U       3.0
# QBC     4.0
# HU      5.0
# US      6.0
# H       7.0
# N1      8.0
# F3      9.0
# RS     10.0
# Name: rank, dtype: float64

# %%
df = df_all[:]

# %% [markdown]
# ## Ranking

# %%
data_acc = pd.pivot_table(df_all, values='accuracy_history', index=['dataset'], columns='strategy')
data_acc = data_acc.apply(lambda x: round(x, 2).rank(method = 'min', ascending = False),axis = 1)
data_acc = data_acc.mean().sort_values(ascending = True)

# %%
pd.DataFrame(data = {"Acurácia":data_acc})
# Out:
#           Acurácia
# strategy
# LSC       3.845070
# EMC       3.971831
# U         4.028169
# QBC       4.197183
# HU        4.309859
# US        5.802817
# H         6.535211
# N1        6.549296
# F3        6.957746
# RS        8.647887

# %%
data_f1 = pd.pivot_table(df_all, values='f1_history', index=['dataset'], columns='strategy')
data_f1 = data_f1.apply(lambda x: round(x, 2).rank(method = 'min', ascending = False),axis = 1)
data_f1 = data_f1.mean().sort_values(ascending = True)

# %%
pd.DataFrame(data = {"F1 Score":data_f1})
# Out:
#           F1 Score
# strategy
# LSC       2.816901
# U         3.366197
# HU        3.661972
# QBC       5.225352
# N1        5.535211
# H         5.605634
# EMC       5.845070
# F3        6.239437
# US        7.140845
# RS        9.323944
